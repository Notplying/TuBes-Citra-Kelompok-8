# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.yaml')

# %%
results = model.train(data=r"Z:\Jupyter Notebook\DatasetTuBesCitra\data.yaml", epochs=1000, batch=80, device=0, project='tubescitra/train', name='default')
# Out:
# New https://pypi.org/project/ultralytics/8.2.28 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.16  Python-3.10.14 torch-2.3.0 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
results = model.train(
    data=r"Z:\Jupyter Notebook\DatasetTuBesCitra\data.yaml", 
    epochs=1000, 
    batch=80, 
    device=0,
    imgsz=416,
    lr0=0.001,
    optimizer='SGD',
    momentum=0.9,
    weight_decay=0.0005,
    augment=False,
    project='tubescitra/train',
    name='speed_efficiency'
)
# Out:
# New https://pypi.org/project/ultralytics/8.2.28 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.16  Python-3.10.14 torch-2.3.0 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
results = model.train(
    data=r"Z:\Jupyter Notebook\DatasetTuBesCitra\data.yaml", 
    epochs=1000, 
    batch=80, 
    device=0,
    imgsz=640,
    lr0=0.0005,
    optimizer='Adam',
    weight_decay=0.0001,
    augment=True,
    project='tubescitra/train',
    name='accuracy_robustness'
)
# Out:
# New https://pypi.org/project/ultralytics/8.2.28 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.16  Python-3.10.14 torch-2.3.0 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
results = model.train(
    data=r"Z:\Jupyter Notebook\DatasetTuBesCitra\data.yaml", 
    epochs=1000, 
    batch=80, 
    device=0,
    imgsz=512,
    lr0=0.00075,
    optimizer='RMSProp',
    weight_decay=0.0001,
    augment=True,
    project='tubescitra/train',
    name='balanced_approach'
)
# Out:
# New https://pypi.org/project/ultralytics/8.2.28 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.16  Python-3.10.14 torch-2.3.0 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
# Test the model 1st 882 Epoch 1.389 Hours
modelval = YOLO(r"Z:\Jupyter Notebook\tubescitra\train\default\weights\best.pt")
metrics = modelval.val(split='test')
# Out:
# Ultralytics YOLOv8.2.16  Python-3.10.14 torch-2.3.0 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLOv8n summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning Z:\Jupyter Notebook\DatasetTuBesCitra\test\labels.cache... 112 images, 0 backgrounds, 0 corrupt: 100%|███
# WARNING  Box and segment counts should be equal, but got len(segments) = 2066, len(boxes) = 2798. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:06<0
#                    all        112       2798      0.966      0.953      0.981      0.928
#                    Car        112       2084      0.979      0.964      0.988      0.957
#                 Vacant        112        714      0.953      0.943      0.973      0.898
# ...

# %%
# Test the model 2nd 948 Epoch 0.912 Hours
modelval = YOLO(r"Z:\Jupyter Notebook\tubescitra\train\speed_efficiency\weights\best.pt")
metrics = modelval.val(split='test')
# Out:
# Ultralytics YOLOv8.2.16  Python-3.10.14 torch-2.3.0 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLOv8n summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning Z:\Jupyter Notebook\DatasetTuBesCitra\test\labels.cache... 112 images, 0 backgrounds, 0 corrupt: 100%|███
# WARNING  Box and segment counts should be equal, but got len(segments) = 2066, len(boxes) = 2798. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<0
#                    all        112       2798      0.964      0.904      0.956      0.843
#                    Car        112       2084      0.971      0.939      0.977       0.88
#                 Vacant        112        714      0.957       0.87      0.934      0.807
# ...

# %%
# Test the model 3rd 1000 Epoch 1.603 Hours
modelval = YOLO(r"Z:\Jupyter Notebook\tubescitra\train\accuracy_robustness\weights\best.pt")
metrics = modelval.val(split='test')
# Out:
# Ultralytics YOLOv8.2.16  Python-3.10.14 torch-2.3.0 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLOv8n summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning Z:\Jupyter Notebook\DatasetTuBesCitra\test\labels.cache... 112 images, 0 backgrounds, 0 corrupt: 100%|███
# WARNING  Box and segment counts should be equal, but got len(segments) = 2066, len(boxes) = 2798. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:03<0
#                    all        112       2798      0.972       0.95      0.979      0.924
#                    Car        112       2084      0.983      0.964      0.988      0.954
#                 Vacant        112        714      0.961      0.937       0.97      0.895
# ...

# %%
# Test the model 4th 189 Epoch 0.225 Hours
modelval = YOLO(r"Z:\Jupyter Notebook\tubescitra\train\balanced_approach\weights\best.pt")
metrics = modelval.val(split='test')
# Out:
# Ultralytics YOLOv8.2.16  Python-3.10.14 torch-2.3.0 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLOv8n summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning Z:\Jupyter Notebook\DatasetTuBesCitra\test\labels.cache... 112 images, 0 backgrounds, 0 corrupt: 100%|███
# WARNING  Box and segment counts should be equal, but got len(segments) = 2066, len(boxes) = 2798. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# ...
